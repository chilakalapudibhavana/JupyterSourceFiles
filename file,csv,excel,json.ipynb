# %%
import sklearn

# %%
import pandas as pd

# %%
data=pd.read_csv('m.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
data=pd.read_csv('bhavs/e.csv')

# %%
data.head(4)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# ...

# %%
import glob

# %%
for directory in glob.glob('bhavs/*'):
    for files in glob.glob(directory + '/*'):
         print(files)
# Out:
# bhavs\Untitled Folder\Untitled Folder
# bhavs\Untitled Folder\Untitled Folder 1

# %%
data=pd.read_csv('bhavs/e.csv')

# %%
data=pd.read_excel('ex1.xlsx')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data=pd.read_excel('ex1.xlsx',skiprows=3)

# %%
data.head()
# Out:
#    FDN15    17.5  Low Fat  0.016760075                   Meat   141.618  \
# 0  FDX07  19.200  Regular     0.000000  Fruits and Vegetables  182.0950
# 1  NCD19   8.930  Low Fat     0.000000              Household   53.8614
# 2  FDP36  10.395  Regular     0.000000           Baking Goods   51.4008
# 3  FDO10  13.650  Regular     0.012741            Snack Foods   57.6588
# 4  FDP10     NaN  Low Fat     0.127470            Snack Foods  107.7622
#
#    OUT049  1999  Medium  Tier 1  Supermarket Type1    2097.27
# 0  OUT010  1998     NaN  Tier 3      Grocery Store   732.3800
# 1  OUT013  1987    High  Tier 3  Supermarket Type1   994.7052
# 2  OUT018  2009  Medium  Tier 3  Supermarket Type2   556.6088
# 3  OUT013  1987    High  Tier 3  Supermarket Type1   343.5528
# 4  OUT027  1985  Medium  Tier 3  Supermarket Type3  4022.7636
